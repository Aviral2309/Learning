# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
my_data = randn(4,3) #Rows, columns
my_rows=["A","B","C","D"]
my_cols=["Monday", "Tuesday","Friday"]

# %%
#create data frame
my_df = pd.DataFrame(my_data, my_rows, my_cols)
my_df
# Out:
#      Monday   Tuesday    Friday
# A  0.452652  0.017096 -1.509868
# B  0.821618 -1.698939  0.254238
# C  2.543123  0.130472  1.740866
# D -1.547783  1.188424  1.895315

# %%
#import csv file
my_df2 = pd.read_csv('csv_sample.csv')
my_df2
# Out:
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95    NaN              NaN        NaN       NaN
# 96    NaN              NaN        NaN       NaN
# 97    NaN              NaN        NaN       NaN
# 98    NaN              NaN        NaN       NaN
# 99    NaN              NaN        NaN       NaN
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# 95                              NaN                NaN
# 96                              NaN                NaN
# 97                              NaN                NaN
# 98                              NaN                NaN
# 99                              NaN                NaN
#
#                        Country                 Phone 1  Unnamed: 8  \
# 0                        Chile            229.077.5154         NaN
# 1                     Djibouti              5153435776         NaN
# 2          Antigua and Barbuda                   -1199         NaN
# 3           Dominican Republic  001-808-617-6467x12895         NaN
# 4   Slovakia (Slovak Republic)  001-234-203-0635x76146         NaN
# ..                         ...                     ...         ...
# 95                         NaN                     NaN         NaN
# 96                         NaN                     NaN         NaN
# 97                         NaN                     NaN         NaN
# 98                         NaN                     NaN         NaN
# 99                         NaN                     NaN         NaN
#
#     Unnamed: 9  Unnamed: 10
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# ..         ...          ...
# 95         NaN          NaN
# 96         NaN          NaN
# 97         NaN          NaN
# 98         NaN          NaN
# 99         NaN          NaN
#
# [100 rows x 11 columns]

# %%
#pull out rows
my_df2.loc[[0,5]]
# Out:
#    Index      Customer Id First Name Last Name          Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group
# 5    6.0  2d08FB17EE273F4      Aimee     Downs     Steele Group
#
#             City                 Country              Phone 1  Unnamed: 8  \
# 0   East Leonard                   Chile         229.077.5154         NaN
# 5  Chavezborough  Bosnia and Herzegovina  (283)437-3886x88321         NaN
#
#    Unnamed: 9  Unnamed: 10
# 0         NaN          NaN
# 5         NaN          NaN
